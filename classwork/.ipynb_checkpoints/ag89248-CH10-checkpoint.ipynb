# %% [markdown]
# Testing

# %%
X = np.sort(random.rand(10))
Y = random.rand(10)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(X)
print(Y)
print(f"Slope: {m}, Intercept: {c}")
# Out:
# [0.08153439 0.21715941 0.2249339  0.31264251 0.33456335 0.38305976
#  0.43888531 0.48704496 0.48763308 0.80739101]
# [0.79383841 0.69882004 0.2934444  0.19464833 0.88412221 0.87726936
#  0.80566574 0.61823356 0.99895139 0.26511949]
# Slope: -0.2707281276382972, Intercept: 0.7452070362286523

# %%
degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
# Out:
# Polynomial Coefficients:  [-19.14525392  23.40746992  -7.65752807   1.25928853]

# %%
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2)
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error Polynomial: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial: {r_squared:.4f}')

mse = np.mean((Y - Y2)**2)
print(f'Mean Squared Error LSTSQ: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - Y2)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared LSTSQ: {r_squared:.4f}')
# Out:
# Mean Squared Error Polynomial: 0.0419
# R-squared Polynomial: 0.4472
# Mean Squared Error LSTSQ: 0.0733
# R-squared LSTSQ: 0.0343

# %%
X = np.sort(random.rand(20))
Y = random.rand(20)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2)

degree = 4
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred2 = polynomial(X)

degree = 5
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred3 = polynomial(X)

degree = 6
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred4 = polynomial(X)

degree = 7
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred5 = polynomial(X)

degree = 15
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred6 = polynomial(X)

degree = 2
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred7 = polynomial(X)

plt.plot(X, y_pred2, label=f'Polynomial fit of degree {4}')
plt.plot(X, y_pred3, label=f'Polynomial fit of degree {5}')
plt.plot(X, y_pred4, label=f'Polynomial fit of degree {6}')
plt.plot(X, y_pred5, label=f'Polynomial fit of degree {7}')
plt.plot(X, y_pred6, label=f'Polynomial fit of degree {15}')
plt.plot(X, y_pred7, label=f'Polynomial fit of degree {2}')
plt.legend()


mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error Polynomial 3: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 3: {r_squared:.4f}')

mse = np.mean((Y - y_pred2)**2)
print(f'Mean Squared Error Polynomial 4: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred2)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 4: {r_squared:.4f}')

mse = np.mean((Y - y_pred3)**2)
print(f'Mean Squared Error Polynomial 5: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred3)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 5: {r_squared:.4f}')

mse = np.mean((Y - y_pred4)**2)
print(f'Mean Squared Error Polynomial 6: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred4)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 6: {r_squared:.4f}')

mse = np.mean((Y - y_pred5)**2)
print(f'Mean Squared Error Polynomial 7: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred5)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 7: {r_squared:.4f}')

mse = np.mean((Y - y_pred6)**2)
print(f'Mean Squared Error Polynomial 8: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred6)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 8: {r_squared:.4f}')

mse = np.mean((Y - y_pred7)**2)
print(f'Mean Squared Error Polynomial 2: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred7)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 2: {r_squared:.4f}')

mse = np.mean((Y - Y2)**2)
print(f'Mean Squared Error LSTSQ: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - Y2)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared LSTSQ: {r_squared:.4f}')
# Out:
# Slope: 0.19524065222551973, Intercept: 0.4229690847401117
# Polynomial Coefficients:  [ 3.28442843 -4.00264806  1.32351829  0.41334958]
# Mean Squared Error Polynomial 3: 0.0746
# R-squared Polynomial 3: 0.0837
# Mean Squared Error Polynomial 4: 0.0741
# R-squared Polynomial 4: 0.0896
# Mean Squared Error Polynomial 5: 0.0728
# R-squared Polynomial 5: 0.1061
# Mean Squared Error Polynomial 6: 0.0728
# R-squared Polynomial 6: 0.1061
# Mean Squared Error Polynomial 7: 0.0708
# R-squared Polynomial 7: 0.1307
# Mean Squared Error Polynomial 8: 0.0155
# R-squared Polynomial 8: 0.8099
# Mean Squared Error Polynomial 2: 0.0770
# R-squared Polynomial 2: 0.0547
# Mean Squared Error LSTSQ: 0.0796
# R-squared LSTSQ: 0.0230
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3326: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def create_vandermonde_matrix(degree, x):
    V = np.zeros(shape=((degree+1), len(x)))
    for i in range(degree+1):
        V[i] = (x.T ** i)
    V = V.T
    return V

# %%
x = np.array([1,2,3])
V = create_vandermonde_matrix(3, x)
print(V)
# Out:
# [[ 1.  1.  1.  1.]
#  [ 1.  2.  4.  8.]
#  [ 1.  3.  9. 27.]]

# %%
def create_vandermonde_polynomial(degree, x, y):
    V = create_vandermonde_matrix(degree, x)
    VT_V = np.dot(V.T, V)
    VT_y = np.dot(V.T, y)
    coefficients = np.linalg.solve(VT_V, VT_y)
    polynomial = np.zeros(len(x))
    for i in range(degree+1):
        polynomial += ((X**i) * coefficients[i])
    return polynomial

# %%
X = np.sort(random.rand(20))
Y = random.rand(20)
y_vand = create_vandermonde_polynomial(5, X, Y)
plt.scatter(X, Y)
plt.plot(X, y_vand, label="vandermont polynomial")
