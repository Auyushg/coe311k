# %% [markdown]
# Testing

# %%
X = np.sort(random.rand(10))
Y = random.rand(10)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(X)
print(Y)
print(f"Slope: {m}, Intercept: {c}")
# Out:
# [0.08028531 0.08644753 0.18804198 0.32897639 0.36899481 0.40267448
#  0.47997166 0.53618302 0.55485034 0.99466757]
# [0.73427688 0.74975389 0.33788452 0.67791312 0.75828757 0.54210968
#  0.73235425 0.08179224 0.48323079 0.48384035]
# Slope: -0.2923445911147255, Intercept: 0.6756988115517699

# %%
degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
# Out:
# Polynomial Coefficients:  [ 2.88197424 -4.0200454   1.01087371  0.60963189]

# %%
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2, label="LSTSQ Estimate")
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
plt.legend()

msep = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error Polynomial: {msep:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squaredp = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial: {r_squaredp:.4f}')

msel = np.mean((Y - Y2)**2)
print(f'Mean Squared Error LSTSQ: {msel:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - Y2)**2)
r_squaredlstsq = 1 - (ss_res / ss_total)
print(f'R-squared LSTSQ: {r_squaredlstsq:.4f}')

if((1-r_squaredp) > (1-r_squaredlstsq)):
    print("LSTSQ Has a better R-Squared value")
else:
    print("Polynomial Has a better R-Squared value")
if((msep) > (msel)):
    print("LSTSQ Has a better MSE value")
else:
    print("Polynomial Has a better MSE value")
# Out:
# Mean Squared Error Polynomial: 0.0354
# R-squared Polynomial: 0.1932
# Mean Squared Error LSTSQ: 0.0383
# R-squared LSTSQ: 0.1272
# Polynomial Has a better R-Squared value
# Polynomial Has a better MSE value

# %% [markdown]
# The polynomial appears to perform better since its R-Squared value is closer to 1 and the MSE is closer to 0

# %%
X = np.sort(random.rand(20))
Y = random.rand(20)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2, label= "LSTSQ Estimate")

degree = 4
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred2 = polynomial(X)

degree = 5
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred3 = polynomial(X)

degree = 6
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred4 = polynomial(X)

degree = 7
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred5 = polynomial(X)

degree = 15
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred6 = polynomial(X)

degree = 2
coefficients = np.polyfit(X, Y, degree)
polynomial = np.poly1d(coefficients)
y_pred7 = polynomial(X)

plt.plot(X, y_pred2, label=f'Polynomial fit of degree {4}')
plt.plot(X, y_pred3, label=f'Polynomial fit of degree {5}')
plt.plot(X, y_pred4, label=f'Polynomial fit of degree {6}')
plt.plot(X, y_pred5, label=f'Polynomial fit of degree {7}')
plt.plot(X, y_pred6, label=f'Polynomial fit of degree {15}')
plt.plot(X, y_pred7, label=f'Polynomial fit of degree {2}')
plt.legend()


mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error Polynomial 3: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 3: {r_squared:.4f}')

mse = np.mean((Y - y_pred2)**2)
print(f'Mean Squared Error Polynomial 4: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred2)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 4: {r_squared:.4f}')

mse = np.mean((Y - y_pred3)**2)
print(f'Mean Squared Error Polynomial 5: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred3)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 5: {r_squared:.4f}')

mse = np.mean((Y - y_pred4)**2)
print(f'Mean Squared Error Polynomial 6: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred4)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 6: {r_squared:.4f}')

mse = np.mean((Y - y_pred5)**2)
print(f'Mean Squared Error Polynomial 7: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred5)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 7: {r_squared:.4f}')

mse = np.mean((Y - y_pred6)**2)
print(f'Mean Squared Error Polynomial 15: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred6)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 15: {r_squared:.4f}')

mse = np.mean((Y - y_pred7)**2)
print(f'Mean Squared Error Polynomial 2: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred7)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Polynomial 2: {r_squared:.4f}')

mse = np.mean((Y - Y2)**2)
print(f'Mean Squared Error LSTSQ: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - Y2)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared LSTSQ: {r_squared:.4f}')
# Out:
# Slope: -0.10211664742382566, Intercept: 0.5017469176429762
# Polynomial Coefficients:  [ 2.79313633 -3.92338898  1.25423019  0.41194371]
# Mean Squared Error Polynomial 3: 0.0721
# R-squared Polynomial 3: 0.0630
# Mean Squared Error Polynomial 4: 0.0582
# R-squared Polynomial 4: 0.2434
# Mean Squared Error Polynomial 5: 0.0458
# R-squared Polynomial 5: 0.4056
# Mean Squared Error Polynomial 6: 0.0454
# R-squared Polynomial 6: 0.4108
# Mean Squared Error Polynomial 7: 0.0423
# R-squared Polynomial 7: 0.4512
# Mean Squared Error Polynomial 15: 0.0038
# R-squared Polynomial 15: 0.9504
# Mean Squared Error Polynomial 2: 0.0760
# R-squared Polynomial 2: 0.0127
# Mean Squared Error LSTSQ: 0.0761
# R-squared LSTSQ: 0.0116

# %% [markdown]
# Based on the fact that polynomail degree 15 has the highest R-squared and lowest MSE, it is the best fit for the data(It overfits!)

# %%
def create_vandermonde_matrix(degree, x):
    V = np.zeros(shape=((degree+1), len(x)))
    for i in range(degree+1):
        V[i] = (x.T ** i)
    V = V.T
    return V

# %%
#Test
x = np.array([1,2,3,4])
V = create_vandermonde_matrix(3, x)
print(V)
# Out:
# [[ 1.  1.  1.  1.]
#  [ 1.  2.  4.  8.]
#  [ 1.  3.  9. 27.]
#  [ 1.  4. 16. 64.]]

# %%
def create_vandermonde_polynomial(degree, x, y):
    V = create_vandermonde_matrix(degree, x)
    VT_V = np.dot(V.T, V)
    VT_y = np.dot(V.T, y)
    coefficients = np.linalg.solve(VT_V, VT_y)
    polynomial = np.zeros(len(x))
    for i in range(degree+1):
        polynomial += ((X**i) * coefficients[i])
    return polynomial

# %%
X = np.sort(random.rand(20))
Y = random.rand(20)
y_vand = create_vandermonde_polynomial(5, X, Y)
plt.scatter(X, Y, label="Points")
plt.plot(X, y_vand, label="vandermonte polynomial")
plt.legend()

mse = np.mean((Y - y_vand)**2)
print(f'Mean Squared Error Vandermonde: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_vand)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared Vandermonde: {r_squared:.4f}')
# Out:
# Mean Squared Error Vandermonde: 0.0438
# R-squared Vandermonde: 0.2903
