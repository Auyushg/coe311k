# %%
import numpy as np
import matplotlib.pyplot as plt
import math


# Define parameters
h = 0.1  # step size
h_list = []
error_list = []
x = 15
k = 1
error_x15_list = []

while h>= .01:
    x_start, x_end = 0, 2 # will reach overflow if I don't set it to 2
    num_steps = int((x_end - x_start) / h)
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)

    # Initial condition
    y_values[0] = 0  # y(0) = 1
    # Function representing dy/dx = -2y
    def f(x, y):
        return -1000 * y + 3000-2000 * math.exp(-1 * x)

    # Implement Euler's method
    for i in range(num_steps):
        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])

    
    

   
        
    """
    
    cs = CubicSpline(x_values, y_values, bc_type='natural')
    y_interp = cs(x_interp)
    
    p_by_p_error = np.abs(y_init_interp - y_interp)
    
    print(f"Overall error as x increases: {p_by_p_error}")
    

    
    total_error = np.abs(np.average(y_values)-np.average(y_init))
    print(f"Total Error: {round(total_error, 2)}")
    
    """

    # Plot the results
    plt.plot(x_values, y_values, label=f"Euler's Method Approximation, h={round(h, 2)}")
    h /= 10

# %%
x_start, x_end = 0, 30
num_steps = int((x_end - x_start) / h)
x_values = np.linspace(x_start, x_end, num_steps + 1)
y_values = np.zeros(num_steps + 1)
for i in range(len(x_values)):
    y_values[i] = 3 - 0.998 * math.exp(-1000 * x_values[i]) - 2.002 * math.exp(-1 * x_values[i])

plt.plot(x_values, y_values, label="Analytical Solution")
