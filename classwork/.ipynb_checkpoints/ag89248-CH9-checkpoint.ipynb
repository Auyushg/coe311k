# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(X)
print(Y)
print(A)
print(f"Slope: {m}, Intercept: {c}")
# Out:
# [1 2 3 4 5]
# [1.2 2.8 3.6 4.5 5.1]
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
plt.scatter(X,Y)
Y2 = X*m + c
plt.plot(X,Y2)

# %% [markdown]
# Testing

# %%
X = np.sort(random.rand(5))
Y = random.rand(5)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(X)
print(Y)
print(f"Slope: {m}, Intercept: {c}")
# Out:
# [0.39527369 0.42333381 0.48421427 0.55368101 0.98721577]
# [0.39901958 0.75878116 0.4544206  0.28104146 0.68279499]
# Slope: 0.27182683547410147, Intercept: 0.36061175639375886

# %%
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2)

# %%
X = np.sort(random.rand(5))
Y = random.rand(5)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(X)
print(Y)
print(f"Slope: {m}, Intercept: {c}")
plt.scatter(X, Y)
Y2 = X * m + c
plt.plot(X, Y2)
# Out:
# [0.70473402 0.7333614  0.90813916 0.90887481 0.97191547]
# [0.15132805 0.2377577  0.64188993 0.50189373 0.16566184]
# Slope: 0.8018832810253272, Intercept: -0.33820986234574785

# %% [markdown]
# Part B
# m = 8.65
# c = 8.82

# %%
X = np.linspace(0, 1, 101)
m = 8.65
c = 8.82
p = random.rand(len(x)) * 2 - 1
Y = m * X + c + p
plt.plot(X, Y)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
Y2 = m * X + c
plt.plot(X, Y2)
print(np.max(p))
print(f"Slope: {m}, Intercept: {c}")
yE = np.abs(Y2 - Y)
maxYE = np.max(yE)
i = np.argwhere(yE == maxYE)[0]
maxXE = X[i]
print(f"Max residual error at X={maxXE}, Y-difference={maxYE}")
minYE = np.min(yE)
i = np.argwhere(yE == minYE)[0]
minXE = X[i]
print(f"Min residual error at X={minXE}, Y-difference={minYE}")
# Out:
# 0.9766156720955053
# Slope: 8.402891366817697, Intercept: 8.97057917872497
# Max residual error at X=[0.2], Y-difference=1.0016219133614985
# Min residual error at X=[0.43], Y-difference=0.0040903074098572745
